# %% [markdown]
# ## Solution Management
#
# All cloud connections must be associated with a configuration object. The configuration process allows you to limit data collection to specific cloud services, regions, and resource groups.
#
# Let's explore the following API's to exercise the lifecycle of the configuration object: https://developer.cisco.com/docs/appdynamics/cloud-connection/#!api-reference
#
# Lets exercise the configuration object lifecycle:
#
#     * Pre-execution steps
#
#     * List Solutions
#
#     * Query Cloud Regions
#
#     * Query Configurations
#
#     * Create Configurations
#
#     * Get a Configuration
#
#     * Update a Configuration
#
#     * Delete a Configuration
#
#
# After you click Run, executions in progress will be denoted by "ln[*]"
#
# PLEASE WAIT FOR EXECUTION TO COMPLETE.

# %% [markdown]
# ### Pre-execution steps
#
# Lets recall the API token created in the previous notebook. Hit Run to set the environment.

# %%
import os
# %store -r appd_token
# %store -r base_url
# %store -r aws_conf_name
os.environ['APPD_TOK'] = appd_token
os.environ['BASE_URL'] = base_url
os.environ['CONF_NAME'] = aws_conf_name
print("Globals set:" + "\n")
print("API Token:" + appd_token + "\n")
print("Base URL:" + base_url + "\n")
print("Configuration Name:" + aws_conf_name + "\n")

# %%
# !fsoc solution unsubscribe spacefleet
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution/spacefleet)ess
# ✓ Platform API call (PATCH /objstore/v1beta/objects/extensibility:solution/spacefleet)ess
# Tenant c4a179c3-14e8-47fb-b0ba-d49c2ad25981 has successfully unsubscribed from solution spacefleet

# %% [markdown]
# ### List Solutions
#
# AppDynamics Cloud as of now supports a subset of the services offered by AWS and Azure. Run the following query to get a list services supported.

# %%
# !fsoc version
# Out:
# fsoc version 0.33.1

# %%
# !fsoc solution list -o json
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution)ess
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution?cursor=MjAw)ess
# {
#     "items": [
#         {
#             "createdAt": "2023-03-24T21:51:17.330Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "extensibility",
#                 "tag": "stable"
#             },
#             "id": "extensibility",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-24T21:51:17.330Z"
#         },
#         {
#             "createdAt": "2023-03-24T21:51:19.881Z",
#             "data": {
#                 "dependencies": [
#                     "extensibility"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "environment",
#                 "tag": "stable"
#             },
#             "id": "environment",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-24T21:51:19.881Z"
#         },
#         {
#             "createdAt": "2023-03-24T23:50:14.448Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "dashui",
#                 "tag": "stable"
#             },
#             "id": "dashui",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-24T23:50:14.448Z"
#         },
#         {
#             "createdAt": "2023-03-24T23:51:59.410Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "iam",
#                 "tag": "stable"
#             },
#             "id": "iam",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-24T23:51:59.410Z"
#         },
#         {
#             "createdAt": "2023-03-25T00:24:10.388Z",
#             "data": {
#                 "dependencies": [
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optimize-jl",
#                 "tag": "stable"
#             },
#             "id": "optimize-jl",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-25T00:24:10.388Z"
#         },
#         {
#             "createdAt": "2023-03-25T00:27:50.512Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "codex",
#                 "tag": "stable"
#             },
#             "id": "codex",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-25T00:27:50.512Z"
#         },
#         {
#             "createdAt": "2023-03-25T02:09:37.378Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexevent2log",
#                 "tag": "stable"
#             },
#             "id": "codexevent2log",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-25T02:09:37.378Z"
#         },
#         {
#             "createdAt": "2023-03-25T04:11:13.601Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "metric2event",
#                 "tag": "stable"
#             },
#             "id": "metric2event",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-25T04:11:13.601Z"
#         },
#         {
#             "createdAt": "2023-03-26T01:00:59.279Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "peternic-test",
#                 "tag": "stable"
#             },
#             "id": "peternic-test",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-26T01:00:59.279Z"
#         },
#         {
#             "createdAt": "2023-03-26T04:24:03.600Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "data_mask_sol",
#                 "tag": "stable"
#             },
#             "id": "data_mask_sol",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-26T04:24:03.600Z"
#         },
#         {
#             "createdAt": "2023-03-26T04:46:37.691Z",
#             "data": {
#                 "dependencies": [
#                     "data_mask_sol"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "voyager_sol",
#                 "tag": "stable"
#             },
#             "id": "voyager_sol",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-26T04:46:37.691Z"
#         },
#         {
#             "createdAt": "2023-03-27T02:16:52.290Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codextrace2event",
#                 "tag": "stable"
#             },
#             "id": "codextrace2event",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T02:16:52.290Z"
#         },
#         {
#             "createdAt": "2023-03-27T04:49:13.382Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexlog2metric",
#                 "tag": "stable"
#             },
#             "id": "codexlog2metric",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T04:49:13.382Z"
#         },
#         {
#             "createdAt": "2023-03-27T08:08:26.798Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexlog2event",
#                 "tag": "stable"
#             },
#             "id": "codexlog2event",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T08:08:26.798Z"
#         },
#         {
#             "createdAt": "2023-03-27T10:56:37.148Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "mask_temp",
#                 "tag": "stable"
#             },
#             "id": "mask_temp",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T10:56:37.148Z"
#         },
#         {
#             "createdAt": "2023-03-27T11:45:39.979Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "zodiac-test-auth",
#                 "tag": "stable"
#             },
#             "id": "zodiac-test-auth",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T11:45:39.979Z"
#         },
#         {
#             "createdAt": "2023-03-27T12:12:53.669Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "zodiac-test-v6",
#                 "tag": "stable"
#             },
#             "id": "zodiac-test-v6",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T12:12:53.669Z"
#         },
#         {
#             "createdAt": "2023-03-27T18:29:53.101Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "kirby-solution-testing-poc",
#                 "tag": "stable"
#             },
#             "id": "kirby-solution-testing-poc",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T18:29:53.101Z"
#         },
#         {
#             "createdAt": "2023-03-27T19:47:30.642Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "zodiac",
#                     "dashui",
#                     "k8s",
#                     "infra",
#                     "apm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "efficiency-profiler",
#                 "tag": "stable"
#             },
#             "id": "efficiency-profiler",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 2,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T20:44:34.093Z"
#         },
#         {
#             "createdAt": "2023-03-27T20:45:46.729Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "preferences",
#                 "tag": "stable"
#             },
#             "id": "preferences",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T20:45:46.729Z"
#         },
#         {
#             "createdAt": "2023-03-27T21:21:05.192Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "dashui",
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "biz-metric",
#                 "tag": "stable"
#             },
#             "id": "biz-metric",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-27T21:21:05.192Z"
#         },
#         {
#             "createdAt": "2023-03-27T22:28:33.748Z",
#             "data": {
#                 "dependencies": [
#                     "agent",
#                     "efficiency-profiler",
#                     "fmm",
#                     "iam",
#                     "k8s",
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optimize",
#                 "tag": "stable"
#             },
#             "id": "optimize",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 3,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-10T21:50:40.750Z"
#         },
#         {
#             "createdAt": "2023-03-28T05:10:19.065Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "infra",
#                     "healthrule",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "db",
#                 "tag": "stable"
#             },
#             "id": "db",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 2,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-01T06:33:54.407Z"
#         },
#         {
#             "createdAt": "2023-03-28T05:26:43.318Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "sapi-solution-v1",
#                 "tag": "stable"
#             },
#             "id": "sapi-solution-v1",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T05:26:43.318Z"
#         },
#         {
#             "createdAt": "2023-03-28T05:35:16.664Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "sum-v2",
#                 "tag": "stable"
#             },
#             "id": "sum-v2",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T05:35:16.664Z"
#         },
#         {
#             "createdAt": "2023-03-28T07:13:33.270Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "testYitong5",
#                 "tag": "stable"
#             },
#             "id": "testYitong5",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T07:13:33.270Z"
#         },
#         {
#             "createdAt": "2023-03-28T07:14:09.195Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac",
#                     "fmm",
#                     "dashui",
#                     "k8s",
#                     "infra",
#                     "cloud",
#                     "apm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "replex-v1",
#                 "tag": "stable"
#             },
#             "id": "replex-v1",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 4,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-11T15:47:46.587Z"
#         },
#         {
#             "createdAt": "2023-03-28T08:35:38.233Z",
#             "data": {
#                 "dependencies": [
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "mr-hankey",
#                 "tag": "stable"
#             },
#             "id": "mr-hankey",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T08:35:38.233Z"
#         },
#         {
#             "createdAt": "2023-03-28T14:44:05.938Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac",
#                     "fmm",
#                     "infra",
#                     "k8s",
#                     "dashui"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "appsec",
#                 "tag": "stable"
#             },
#             "id": "appsec",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T14:44:05.938Z"
#         },
#         {
#             "createdAt": "2023-03-28T15:32:50.143Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule",
#                     "infra"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "cloud",
#                 "tag": "stable"
#             },
#             "id": "cloud",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T15:32:50.143Z"
#         },
#         {
#             "createdAt": "2023-03-28T15:34:32.881Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule",
#                     "infra",
#                     "cloud"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "aws",
#                 "tag": "stable"
#             },
#             "id": "aws",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T15:34:32.881Z"
#         },
#         {
#             "createdAt": "2023-03-28T15:36:41.264Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule",
#                     "infra",
#                     "cloud"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "azure",
#                 "tag": "stable"
#             },
#             "id": "azure",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T15:36:41.264Z"
#         },
#         {
#             "createdAt": "2023-03-28T16:16:23.574Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "businesstransaction",
#                 "tag": "stable"
#             },
#             "id": "businesstransaction",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T16:16:23.574Z"
#         },
#         {
#             "createdAt": "2023-03-28T17:23:49.880Z",
#             "data": {
#                 "dependencies": [
#                     "data_mask_sol_1",
#                     "logs",
#                     "zodiac",
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "chrisplo",
#                 "tag": "stable"
#             },
#             "id": "chrisplo",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 3,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-18T15:15:51.699Z"
#         },
#         {
#             "createdAt": "2023-03-28T17:34:36.814Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "logs",
#                 "tag": "stable"
#             },
#             "id": "logs",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T17:34:36.814Z"
#         },
#         {
#             "createdAt": "2023-03-28T19:13:30.322Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "healthrule",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "kafka",
#                 "tag": "stable"
#             },
#             "id": "kafka",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T19:13:30.322Z"
#         },
#         {
#             "createdAt": "2023-03-28T19:14:26.998Z",
#             "data": {
#                 "dependencies": [
#                     "agent",
#                     "efficiency-profiler",
#                     "fmm",
#                     "iam",
#                     "k8s",
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optimize-ls",
#                 "tag": "stable"
#             },
#             "id": "optimize-ls",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 3,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-14T21:04:14.105Z"
#         },
#         {
#             "createdAt": "2023-03-28T19:17:51.300Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "healthrule",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "redis",
#                 "tag": "stable"
#             },
#             "id": "redis",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T19:17:51.300Z"
#         },
#         {
#             "createdAt": "2023-03-28T19:51:46.563Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "agent",
#                     "zodiac",
#                     "efficiency-profiler"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "o198-0",
#                 "tag": "stable"
#             },
#             "id": "o198-0",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T19:51:46.563Z"
#         },
#         {
#             "createdAt": "2023-03-28T20:54:22.796Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule",
#                     "infra"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "onprem",
#                 "tag": "stable"
#             },
#             "id": "onprem",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 2,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T22:44:33.202Z"
#         },
#         {
#             "createdAt": "2023-03-28T23:58:21.632Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "eum",
#                 "tag": "stable"
#             },
#             "id": "eum",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-28T23:58:21.632Z"
#         },
#         {
#             "createdAt": "2023-03-29T03:18:41.667Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "agent",
#                     "zodiac",
#                     "efficiency-profiler"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optimize-vs",
#                 "tag": "stable"
#             },
#             "id": "optimize-vs",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T03:18:41.667Z"
#         },
#         {
#             "createdAt": "2023-03-29T03:27:14.279Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "dashbase-index-partition-workflows",
#                 "tag": "stable"
#             },
#             "id": "dashbase-index-partition-workflows",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T03:27:14.279Z"
#         },
#         {
#             "createdAt": "2023-03-29T04:11:18.415Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "entity-metadata",
#                 "tag": "stable"
#             },
#             "id": "entity-metadata",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T04:11:18.415Z"
#         },
#         {
#             "createdAt": "2023-03-29T06:51:33.526Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "logs"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "hockey",
#                 "tag": "stable"
#             },
#             "id": "hockey",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T06:51:33.526Z"
#         },
#         {
#             "createdAt": "2023-03-29T06:59:47.427Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "schooltest",
#                 "tag": "stable"
#             },
#             "id": "schooltest",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T06:59:47.427Z"
#         },
#         {
#             "createdAt": "2023-03-29T09:25:44.261Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexqeevent2event",
#                 "tag": "stable"
#             },
#             "id": "codexqeevent2event",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T09:25:44.261Z"
#         },
#         {
#             "createdAt": "2023-03-29T10:33:13.676Z",
#             "data": {
#                 "dependencies": [
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexqe",
#                 "tag": "stable"
#             },
#             "id": "codexqe",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T10:33:13.676Z"
#         },
#         {
#             "createdAt": "2023-03-29T10:42:42.212Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexlog2log",
#                 "tag": "stable"
#             },
#             "id": "codexlog2log",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T10:42:42.212Z"
#         },
#         {
#             "createdAt": "2023-03-29T11:24:29.266Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexqa",
#                 "tag": "stable"
#             },
#             "id": "codexqa",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T11:24:29.266Z"
#         },
#         {
#             "createdAt": "2023-03-29T13:03:22.558Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexqelog2rawm",
#                 "tag": "stable"
#             },
#             "id": "codexqelog2rawm",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T13:03:22.558Z"
#         },
#         {
#             "createdAt": "2023-03-29T13:15:34.517Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codexqeevent2eventrm",
#                 "tag": "stable"
#             },
#             "id": "codexqeevent2eventrm",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T13:15:34.517Z"
#         },
#         {
#             "createdAt": "2023-03-29T13:50:32.186Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "zodiac-ce-subscription-demo",
#                 "tag": "stable"
#             },
#             "id": "zodiac-ce-subscription-demo",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T13:50:32.186Z"
#         },
#         {
#             "createdAt": "2023-03-29T14:10:48.350Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "zodiac-test-ce-subscription",
#                 "tag": "stable"
#             },
#             "id": "zodiac-test-ce-subscription",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T14:10:48.350Z"
#         },
#         {
#             "createdAt": "2023-03-29T14:29:57.085Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "event2metric",
#                 "tag": "stable"
#             },
#             "id": "event2metric",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T14:29:57.085Z"
#         },
#         {
#             "createdAt": "2023-03-29T21:37:26.683Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "nhandaSecret",
#                 "tag": "stable"
#             },
#             "id": "nhandaSecret",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T21:37:26.683Z"
#         },
#         {
#             "createdAt": "2023-03-29T21:44:43.137Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "topology-test",
#                 "tag": "stable"
#             },
#             "id": "topology-test",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T21:44:43.137Z"
#         },
#         {
#             "createdAt": "2023-03-29T23:34:47.174Z",
#             "data": {
#                 "dependencies": [
#                     "dashui",
#                     "fmm",
#                     "zodiac",
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "geometry",
#                 "tag": "stable"
#             },
#             "id": "geometry",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-29T23:34:47.174Z"
#         },
#         {
#             "createdAt": "2023-03-30T01:07:07.554Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "fsoqe-minimal-solution",
#                 "tag": "stable"
#             },
#             "id": "fsoqe-minimal-solution",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-30T01:07:07.554Z"
#         },
#         {
#             "createdAt": "2023-03-30T05:18:30.384Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "fmmdemo",
#                 "tag": "stable"
#             },
#             "id": "fmmdemo",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 2,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-31T01:26:41.405Z"
#         },
#         {
#             "createdAt": "2023-03-30T08:44:18.322Z",
#             "data": {
#                 "dependencies": [
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "audit",
#                 "tag": "stable"
#             },
#             "id": "audit",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-30T08:44:18.322Z"
#         },
#         {
#             "createdAt": "2023-03-30T12:32:39.190Z",
#             "data": {
#                 "dependencies": [
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "codextrace2log",
#                 "tag": "stable"
#             },
#             "id": "codextrace2log",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-03-30T12:32:39.190Z"
#         },
#         {
#             "createdAt": "2023-03-30T13:53:32.707Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "agent",
#                     "zodiac",
#                     "efficiency-profiler"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optml-ci-0",
#                 "tag": "stable"
#             },
#             "id": "optml-ci-0",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
# ...
#                 "name": "testing-upload-fsoc12",
#                 "tag": "stable"
#             },
#             "id": "testing-upload-fsoc12",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T00:50:41.178Z"
#         },
#         {
#             "createdAt": "2023-04-19T02:23:04.265Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "testing1",
#                 "tag": "stable"
#             },
#             "id": "testing1",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T02:23:04.265Z"
#         },
#         {
#             "createdAt": "2023-04-19T02:25:09.627Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "testing2",
#                 "tag": "stable"
#             },
#             "id": "testing2",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T02:25:09.627Z"
#         },
#         {
#             "createdAt": "2023-04-19T04:12:27.755Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "infra",
#                     "healthrule",
#                     "common"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "dbdemo",
#                 "tag": "stable"
#             },
#             "id": "dbdemo",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T04:12:27.755Z"
#         },
#         {
#             "createdAt": "2023-04-19T05:20:24.785Z",
#             "data": {
#                 "dependencies": [
#                     "dashui"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "d1",
#                 "tag": "stable"
#             },
#             "id": "d1",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T05:20:24.785Z"
#         },
#         {
#             "createdAt": "2023-04-19T08:17:21.587Z",
#             "data": {
#                 "dependencies": [
#                     "agent",
#                     "fmm",
#                     "iam",
#                     "k8s",
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "optml-cd-23-4-0-65",
#                 "tag": "stable"
#             },
#             "id": "optml-cd-23-4-0-65",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T08:17:21.587Z"
#         },
#         {
#             "createdAt": "2023-04-19T16:37:34.739Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "testing3",
#                 "tag": "stable"
#             },
#             "id": "testing3",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T16:37:34.739Z"
#         },
#         {
#             "createdAt": "2023-04-19T18:43:10.472Z",
#             "data": {
#                 "dependencies": [
#                     "voyager_sol"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "d2",
#                 "tag": "stable"
#             },
#             "id": "d2",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T18:43:10.472Z"
#         },
#         {
#             "createdAt": "2023-04-19T19:13:30.175Z",
#             "data": {
#                 "dependencies": [
#                     "zodiac"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "foleyj-test1",
#                 "tag": "stable"
#             },
#             "id": "foleyj-test1",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T19:13:30.175Z"
#         },
#         {
#             "createdAt": "2023-04-19T21:27:46.969Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "coder232-empty-solution",
#                 "tag": "stable"
#             },
#             "id": "coder232-empty-solution",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T21:27:46.969Z"
#         },
#         {
#             "createdAt": "2023-04-19T21:50:51.043Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "askorion-limits",
#                 "tag": "stable"
#             },
#             "id": "askorion-limits",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T21:50:51.043Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:47:18.304Z",
#             "data": {
#                 "dependencies": [
#                     "spacefleet"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": false,
#                 "name": "patsolution",
#                 "tag": "stable"
#             },
#             "id": "patsolution",
#             "layerId": "c4a179c3-14e8-47fb-b0ba-d49c2ad25981",
#             "layerType": "TENANT",
#             "objectMimeType": "application/merge-patch+json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": {
#                 "isSubscribed": true
#             },
#             "targetObjectId": "patsolution",
#             "updatedAt": "2023-04-19T23:47:18.304Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:47:32.139Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": false,
#                 "name": "infra",
#                 "tag": "stable"
#             },
#             "id": "infra",
#             "layerId": "c4a179c3-14e8-47fb-b0ba-d49c2ad25981",
#             "layerType": "TENANT",
#             "objectMimeType": "application/merge-patch+json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": {
#                 "isSubscribed": true
#             },
#             "targetObjectId": "infra",
#             "updatedAt": "2023-04-19T23:47:32.139Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:47:32.192Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "common",
#                     "infra",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": false,
#                 "name": "k8s",
#                 "tag": "stable"
#             },
#             "id": "k8s",
#             "layerId": "c4a179c3-14e8-47fb-b0ba-d49c2ad25981",
#             "layerType": "TENANT",
#             "objectMimeType": "application/merge-patch+json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": {
#                 "isSubscribed": true
#             },
#             "targetObjectId": "k8s",
#             "updatedAt": "2023-04-19T23:47:32.192Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:47:32.235Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "zodiac",
#                 "tag": "stable"
#             },
#             "id": "zodiac",
#             "layerId": "c4a179c3-14e8-47fb-b0ba-d49c2ad25981",
#             "layerType": "TENANT",
#             "objectMimeType": "application/merge-patch+json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": {
#                 "isSubscribed": true
#             },
#             "targetObjectId": "zodiac",
#             "updatedAt": "2023-04-19T23:47:32.235Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:47:32.284Z",
#             "data": {
#                 "dependencies": [
#                     "dashui",
#                     "fmm",
#                     "k8s",
#                     "zodiac",
#                     "codex",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": false,
#                 "name": "spacefleet",
#                 "tag": "stable"
#             },
#             "id": "spacefleet",
#             "layerId": "c4a179c3-14e8-47fb-b0ba-d49c2ad25981",
#             "layerType": "TENANT",
#             "objectMimeType": "application/merge-patch+json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 7,
#             "patch": {
#                 "isSubscribed": true
#             },
#             "targetObjectId": "spacefleet",
#             "updatedAt": "2023-04-20T17:38:13.624Z"
#         },
#         {
#             "createdAt": "2023-04-19T23:57:41.817Z",
#             "data": {
#                 "dependencies": [
#                     "dashui",
#                     "fmm",
#                     "k8s",
#                     "zodiac",
#                     "codex"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "spacefleetv2",
#                 "tag": "stable"
#             },
#             "id": "spacefleetv2",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-19T23:57:41.817Z"
#         },
#         {
#             "createdAt": "2023-04-20T06:16:14.720Z",
#             "data": {
#                 "dependencies": [
#                     "fmm"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "troubleshooting",
#                 "tag": "stable"
#             },
#             "id": "troubleshooting",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-20T06:16:14.720Z"
#         },
#         {
#             "createdAt": "2023-04-20T08:42:36.519Z",
#             "data": {
#                 "dependencies": [
#                     "dashui",
#                     "k8s"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "uitesting",
#                 "tag": "stable"
#             },
#             "id": "uitesting",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-20T08:42:36.519Z"
#         },
#         {
#             "createdAt": "2023-04-20T09:10:49.944Z",
#             "data": {
#                 "dependencies": [],
#                 "isNonStableTag": false,
#                 "isSubscribed": true,
#                 "isSystem": true,
#                 "name": "licensing",
#                 "tag": "stable"
#             },
#             "id": "licensing",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-20T09:10:49.944Z"
#         },
#         {
#             "createdAt": "2023-04-20T16:18:50.130Z",
#             "data": {
#                 "dependencies": [
#                     "fmm",
#                     "healthrule"
#                 ],
#                 "isNonStableTag": false,
#                 "isSubscribed": false,
#                 "isSystem": false,
#                 "name": "school",
#                 "tag": "stable"
#             },
#             "id": "school",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:solution",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-20T16:18:50.130Z"
#         }
#     ],
#     "total": 241
# }

# %%
# !fsoc solution list -o json| jq -r '.items[] | select( .data.name == "spacefleet") | .data'
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution)ess
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution?cursor=MjAw)ess
# {
#   "dependencies": [
#     "dashui",
#     "fmm",
#     "k8s",
#     "zodiac",
#     "codex",
#     "healthrule"
#   ],
#   "isNonStableTag": false,
#   "isSubscribed": false,
#   "isSystem": false,
#   "name": "spacefleet",
#   "tag": "stable"
# }

# %%
# !fsoc solution status spacefleet
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solutionRelease?order=desc&filter=data.solutionName+eq+%22spacefleet%22&max=1)ess
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solutionInstall?order=desc&filter=data.solutionName+eq+%22spacefleet%22&max=1)ess
#                Solution Name:
#      Solution Upload Version:
#             Upload Timestamp:
#     Solution Install Version:
# Solution Install Successful?: false
#        Solution Install Time:
#     Solution Install Message:

# %%
# !fsoc solution subscribe spacefleet
# Out:
# ✓ Platform API call (PATCH /objstore/v1beta/objects/extensibility:solution/spacefleet)ess
# Tenant c4a179c3-14e8-47fb-b0ba-d49c2ad25981 has successfully subscribed to solution spacefleet

# %%
# !fsoc solution list -o json| jq -r '.items[] | select( .data.name == "spacefleet") | .data'
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution)ess
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solution?cursor=MjAw)ess
# {
#   "dependencies": [
#     "dashui",
#     "fmm",
#     "k8s",
#     "zodiac",
#     "codex",
#     "healthrule"
#   ],
#   "isNonStableTag": false,
#   "isSubscribed": true,
#   "isSystem": false,
#   "name": "spacefleet",
#   "tag": "stable"
# }

# %%
# !fsoc solution status spacefleet
# Out:
#    • Current token is no longer valid; trying to refreshelease?order=desc&filter=data.solutionName+eq+%22spacefleet%22&max=1) in progress
# ✓ Exchange service principal for auth token progress
# ✓ Platform API call, retry after login (GET /objstore/v1beta/objects/extensibility:solutionRelease?order=desc&filter=data.solutionName+eq+%22spacefleet%22&max=1)25h
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:solutionInstall?order=desc&filter=data.solutionName+eq+%22spacefleet%22&max=1)ess
#                Solution Name: spacefleet
#      Solution Upload Version: 0.0.300
#             Upload Timestamp: 2023-04-20T13:43:55.186Z
#     Solution Install Version: 0.0.300
# Solution Install Successful?: true
#        Solution Install Time: 2023-04-20T16:44:16.046Z
#     Solution Install Message:

# %%
# !fsoc solution init sample
# Out:
# Preparing the solution folder structure for "sample"...
# Adding the manifest.json

# %%
# !ls sample
# Out:
# manifest.json

# %%
# !cat ./sample/manifest.json
# Out:
# {
#     "manifestVersion": "1.0.0",
#     "name": "sample",
#     "solutionVersion": "1.0.0",
#     "dependencies": [],
#     "description": "description of your solution",
#     "contact": "the email for this solution's point of contact",
#     "homepage": "the url for this solution's homepage",
#     "gitRepoUrl": "the url for the git repo holding your solution",
#     "readme": "the url for this solution's readme file"
# }

# %%
# !echo "{\
    "manifestVersion": "1.0.0",\
    "name": "sample",\
    "solutionVersion": "1.0.0",\
    "dependencies": ["spacefleet"],\
    "description": "description of your solution",\
    "contact": "the email for this solution\'s point of contact",\
    "homepage": "the url for this solution\'s homepage",\
    "gitRepoUrl": "the url for the git repo holding your solution",\
    "readme": "the url for this solution\'s readme file"\
}" > ./sample/manifest.json

# !!cat ./sample/manifest.json
# Out:
# ["{     manifestVersion: 1.0.0,     name: sample,     solutionVersion: 1.0.0,     dependencies: [spacefleet],     description: description of your solution,     contact: the email for this solution's point of contact,     homepage: the url for this solution's homepage,     gitRepoUrl: the url for the git repo holding your solution,     readme: the url for this solution's readme file }"]

# %%
# !fsoc knowledge get --type extensibility:type --layer-type TENANT --filter "data.solution eq \"spacefleet\"" -o json
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/extensibility:type?filter=data.solution+eq+%22spacefleet%22)ess
# {
#     "items": [
#         {
#             "createdAt": "2023-04-13T14:30:06.486Z",
#             "data": {
#                 "allowedLayers": [
#                     "TENANT"
#                 ],
#                 "allowedObjectFragments": false,
#                 "idGeneration": {
#                     "generateRandomId": false,
#                     "idGenerationMechanism": "{{layer.id}}:{{object.name}}"
#                 },
#                 "jsonSchema": {
#                     "$schema": "http://json-schema.org/draft-07/schema#",
#                     "additionalProperties": false,
#                     "description": "Type for storing config for calling the news of the day service",
#                     "properties": {
#                         "api_key": {
#                             "description": "Api Key for news endpoint",
#                             "type": "string"
#                         },
#                         "name": {
#                             "description": "Config Name",
#                             "type": "string"
#                         }
#                     },
#                     "required": [
#                         "name",
#                         "api_key"
#                     ],
#                     "title": "NewsOfTheDayConfig",
#                     "type": "object"
#                 },
#                 "name": "notdConfig",
#                 "secureProperties": [
#                     "$.api_key"
#                 ],
#                 "solution": "spacefleet"
#             },
#             "id": "spacefleet:notdConfig",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:type",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-13T14:30:06.486Z"
#         },
#         {
#             "createdAt": "2023-04-13T14:30:06.492Z",
#             "data": {
#                 "allowedLayers": [
#                     "SOLUTION",
#                     "TENANT"
#                 ],
#                 "allowedObjectFragments": false,
#                 "idGeneration": {
#                     "generateRandomId": false,
#                     "idGenerationMechanism": "{{layer.id}}:{{object.spacecraft_name}}:{{object.torpedo_tube_id}}"
#                 },
#                 "jsonSchema": {
#                     "$schema": "http://json-schema.org/draft-07/schema#",
#                     "additionalProperties": false,
#                     "description": "Definition of a type of Torpedo State",
#                     "properties": {
#                         "count": {
#                             "description": "Count",
#                             "type": "integer"
#                         },
#                         "spacecraft_name": {
#                             "description": "Spacecraft Name",
#                             "type": "string"
#                         },
#                         "torpedo_tube_id": {
#                             "description": "Torpedo Tube Id",
#                             "type": "string"
#                         }
#                     },
#                     "required": [
#                         "spacecraft_name",
#                         "torpedo_tube_id",
#                         "count"
#                     ],
#                     "title": "TorpedoState",
#                     "type": "object"
#                 },
#                 "name": "torpedoState",
#                 "solution": "spacefleet"
#             },
#             "id": "spacefleet:torpedoState",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:type",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-13T14:30:06.492Z"
#         },
#         {
#             "createdAt": "2023-04-13T14:30:06.498Z",
#             "data": {
#                 "allowedLayers": [
#                     "SOLUTION",
#                     "TENANT"
#                 ],
#                 "allowedObjectFragments": false,
#                 "blobProperties": [
#                     "$.image"
#                 ],
#                 "idGeneration": {
#                     "generateRandomId": false,
#                     "idGenerationMechanism": "{{layer.id}}:{{object.name}}"
#                 },
#                 "jsonSchema": {
#                     "$schema": "http://json-schema.org/draft-07/schema#",
#                     "additionalProperties": false,
#                     "description": "Definition of a type of StarJournal",
#                     "properties": {
#                         "image": {
#                             "contentEncoding": "base64",
#                             "description": "Image for the journal",
#                             "type": "string"
#                         },
#                         "instrument": {
#                             "description": "Instrument used for measurement",
#                             "type": "string"
#                         },
#                         "journal": {
#                             "description": "Journal entry",
#                             "type": "string"
#                         },
#                         "magnification": {
#                             "description": "Magnfication factor",
#                             "type": "integer"
#                         },
#                         "name": {
#                             "description": "Journal entry name",
#                             "type": "string"
#                         }
#                     },
#                     "required": [
#                         "name",
#                         "journal"
#                     ],
#                     "title": "StarJournal",
#                     "type": "object"
#                 },
#                 "name": "starjournal",
#                 "solution": "spacefleet"
#             },
#             "id": "spacefleet:starjournal",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:type",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-13T14:30:06.498Z"
#         },
#         {
#             "createdAt": "2023-04-13T14:30:06.503Z",
#             "data": {
#                 "allowedLayers": [
#                     "SOLUTION",
#                     "TENANT"
#                 ],
#                 "allowedObjectFragments": false,
#                 "idGeneration": {
#                     "generateRandomId": false,
#                     "idGenerationMechanism": "{{layer.id}}:{{object.name}}"
#                 },
#                 "jsonSchema": {
#                     "$schema": "http://json-schema.org/draft-07/schema#",
#                     "additionalProperties": false,
#                     "description": "Definition of an FSO Exchange Object",
#                     "properties": {
#                         "description": {
#                             "description": "solution description",
#                             "type": "string"
#                         },
#                         "name": {
#                             "description": "name of the solution",
#                             "type": "string"
#                         },
#                         "thumbnail_url": {
#                             "description": "Thumbnail URL",
#                             "type": "string"
#                         }
#                     },
#                     "required": [
#                         "name",
#                         "description"
#                     ],
#                     "title": "FSO Exchange Object",
#                     "type": "object"
#                 },
#                 "name": "fsoExchangeObject",
#                 "solution": "spacefleet"
#             },
#             "id": "spacefleet:fsoExchangeObject",
#             "layerId": "extensibility",
#             "layerType": "SOLUTION",
#             "objectMimeType": "application/json",
#             "objectType": "extensibility:type",
#             "objectVersion": 1,
#             "patch": null,
#             "targetObjectId": null,
#             "updatedAt": "2023-04-13T14:30:06.503Z"
#         }
#     ],
#     "total": 4
# }

# %%
# !fsoc knowledge get --type extensibility:type --layer-type TENANT --filter "data.solution eq \"spacefleet\"" -o json | jq -r '.items[] | .data.name'
# Out:
#    • Current token is no longer valid; trying to refreshype?filter=data.solution+eq+%22spacefleet%22) in progress
# ✓ Exchange service principal for auth token progress
# ✓ Platform API call, retry after login (GET /objstore/v1beta/objects/extensibility:type?filter=data.solution+eq+%22spacefleet%22)ess
# notdConfig
# torpedoState
# starjournal
# fsoExchangeObject

# %%
# !fsoc knowledge get --type spacefleet:fsoExchangeObject --layer-type TENANT
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/spacefleet:fsoExchangeObject)ess
# items: []
# total: 0

# %%
# !fsoc knowledge get --type spacefleet:notdConfig --layer-type TENANT
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/spacefleet:notdConfig)ess
# items: []
# total: 0

# %%
# !fsoc knowledge get --type spacefleet:torpedoState --layer-type TENANT
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/spacefleet:torpedoState)ess
# items: []
# total: 0

# %%
# !fsoc knowledge get --type spacefleet:starjournal --layer-type TENANT
# Out:
# ✓ Platform API call (GET /objstore/v1beta/objects/spacefleet:starjournal)ess
# items: []
# total: 0

# %%
import os, requests, json

def get_all_aws_services(appd_token, base_url):
    url = base_url + "/cloud/v1/services"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'type': 'aws'}
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        print("AWS Services:")
        print(json.dumps(json_object, indent = 3))
    else:
        print("Unable to retrieve AWS Services.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
get_all_aws_services(appd_token, base_url)

# %% [markdown]
# ### Query Cloud Regions
#
# AppDynamics Cloud as of now supports a subset of the regions offered by AWS and Azure. Run the following queries to get a list regions supported.

# %%
import os, requests, json

def get_all_aws_regions(appd_token, base_url):
    #url = base_url + "/cloud/v1/services"
    url = base_url + "/cloud/v1/regions"
    
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'type': 'aws'}
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        print("AWS Regions:")
        print(json.dumps(json_object, indent = 3))
    else:
        print("Unable to retrieve AWS Regions.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
get_all_aws_regions(appd_token, base_url)

# %% [markdown]
# ### Query Configuration objects
#
# Configurations query results can be filtered. Following exercises some of the filters supported. Run each of the following and examine the results:
#
#     * get_all_configurations - Get all Configuration objects
#
#     * get_all_aws_configurations - Get all AWS Configuration objects
#
#     * get_aws_configurationid_by_name - Get the Configuration object corresponding to a given name
#
# Above are some of the more basic filtering examples. For more filter configuration, check out: https://developer.cisco.com/docs/appdynamics/cloud-connection/#!api-reference

# %%
import os, requests, json

def get_all_configurations(appd_token, base_url):
    url = base_url + "/cloud/v1/configurations"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    response = requests.request("GET", url, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        print("All Configurations:")
        print(json.dumps(json_object, indent = 3))
    else:
        print("Unable to retrieve Configurations.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
get_all_configurations(appd_token, base_url)

# %%
import os, requests, json

def get_all_aws_configurations(appd_token, base_url):
    url = base_url + "/cloud/v1/configurations"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'filter': 'type eq "aws"'}
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        print("AWS Configurations:")
        print(json.dumps(json_object, indent = 3))
    else:
        print("Unable to retrieve AWS Configurations.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
get_all_aws_configurations(appd_token, base_url)

# %%
import os, requests, json

def get_aws_configurationid_by_name(appd_token, base_url, conf_name):
    url = base_url + "/cloud/v1/configurations"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'filter': 'type eq "aws" and displayName eq "' + conf_name + "\""}
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        items = json_object['items']
        if not items:
            return None
        else:
            print("AWS Configuration found for " + conf_name + ":")
            print(json.dumps(json_object, indent = 3))
        return(json_object['items'][0]['id'])
    else:
        return None

appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
conf_name = "JupyterAWSConfig"
item = get_aws_configurationid_by_name(appd_token, base_url, conf_name)
if not item:
    print ("Configuration not found for:" + conf_name)
else:
    print("Configuration ID:" + item)

# %% [markdown]
# ### Create Configuration objects
#
# Let's create a configuration object that will limit data collection to specific cloud services, regions, and resource groups. We will enable data collection only to EC2 instances and apply it to all regions. We will later use this same configuration to create a cloud connection to AWS.

# %%
import os, requests, json

def create_aws_config(appd_token, base_url, conf_name):
    url = base_url + "/cloud/v1/configurations"
    headers = {
        'Content-Type': 'application/json',
        'Accept': '*/*',
        'Authorization': 'Bearer ' + appd_token
    }
    data = {
        "displayName": conf_name,
        "type": "aws",
        "details": {
            "regions": [],
            "polling": {
                "interval": 5,
                "unit": "minute"
            },
            "services": [{
                "name": "ec2",
                "polling": {
                    "interval": 5,
                    "unit": "minute"
                }
            }],
            "importTags": {
                "enabled": "true",
                "excludedKeys": []
            }
        }
    }
    response = requests.request("POST", url, headers=headers, data=json.dumps(data))
    if response.ok:
        json_object = json.loads(response.text)
        print("AWS Configuration created:")
        print(json.dumps(json_object, indent = 3))
        token_json = response.json()
        cid = token_json['id']
        os.environ['CID'] = cid
        print(cid)
    else:
        print ("Could not create Configuration object. May already exist.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
conf_name = os.getenv('CONF_NAME')
create_aws_config(appd_token, base_url, conf_name)

# %% [markdown]
# ### Update Configuration Objects
#
# Lets update the above configuration object and include regions in its configuration.

# %%
import os, requests, json

def get_aws_configurationid_by_name(appd_token, base_url, conf_name):
    url = base_url + "/cloud/v1/configurations"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'filter': 'type eq "aws" and displayName eq "' + conf_name + "\""}
    print(params)
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        items = json_object['items']
        if not items:
            return None
        else:
            print("AWS Configuration found:")
            print(json.dumps(json_object, indent = 3))
        return(json_object['items'][0]['id'])
    else:
        return None
    
def update_aws_config(appd_token, base_url, cid, conf_name):
    url = base_url + "/cloud/v1/configurations/" + cid
    headers = {
        'Content-Type': 'application/json',
        'Accept': '*/*',
        'Authorization': 'Bearer ' + appd_token
    }
    data = {
        "displayName": conf_name,
        "details": {
            "regions": [
              "us-east-1",
              "us-west-1"
            ],
            "polling": {
                "interval": 5,
                "unit": "minute"
            },
            "services": [{
                "name": "ec2",
                "polling": {
                    "interval": 5,
                    "unit": "minute"
                }
            }],
            "importTags": {
                "enabled": "true",
                "excludedKeys": []
            }
        }
    }
    response = requests.request("PATCH", url, headers=headers, data=json.dumps(data))
    if response.ok:
        print("Updated Configuration:")
        json_object = json.loads(response.text)
        print(json.dumps(json_object, indent = 3)) 
    else:
        print ("Could not update Configuration object. Try again.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
conf_name = os.getenv('CONF_NAME')
#cid = os.getenv('CID')
cid = get_aws_configurationid_by_name(appd_token, base_url, conf_name)
if not cid:
    print("Unknown configuration, cannot update")
else:
    update_aws_config(appd_token, base_url, cid, conf_name)

# %% [markdown]
# ### Delete Configuration Objects
#
# Lets delete the above configuration object created.

# %%
import os, requests, json

def get_aws_configurationid_by_name(appd_token, base_url, conf_name):
    url = base_url + "/cloud/v1/configurations"
    payload={}
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'Bearer ' + appd_token
    }
    params = {'filter': 'type eq "aws" and displayName eq "' + conf_name + "\""}
    response = requests.request("GET", url, params=params, headers=headers, data=payload)
    if response.ok:
        json_object = json.loads(response.text)
        items = json_object['items']
        if not items:
            return None
        else:
            print("AWS Configuration found:")
            print(json.dumps(json_object, indent = 3))
        return(json_object['items'][0]['id'])
    else:
        return None
    
def delete_aws_config(appd_token, config_id):
    url = base_url + "/cloud/v1/configurations/" + config_id
    headers = {
        'Content-Type': 'application/json',
        'Accept': '*/*',
        'Authorization': 'Bearer ' + appd_token
    }
    response = requests.request("DELETE", url, headers=headers)
    if response.ok:
        print("Successfully deleted configuration.")
    else:
        print ("Could not delete Configuration object.")
    
appd_token = os.getenv('APPD_TOK')
base_url = os.getenv('BASE_URL')
conf_name = os.getenv('CONF_NAME')
#cid = os.getenv('CID')
cid = get_aws_configurationid_by_name(appd_token, base_url, conf_name)
if not cid:
    print("Unknown configuration, cannot delete")
else:
    delete_aws_config(appd_token, cid)

# %% [markdown]
# ## Next Steps
#
# In the next section, we shall use the configuration object to create a AWS Cloud Connection.
